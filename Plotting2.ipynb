# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
df1=pd.read_csv('Muestras/Muestras-Raúl/Activacion.csv')
df2=pd.read_csv('Muestras/Muestras-Daniel/Activacion.csv')

# %%
cambios=df1[df1['Tiempo']=='Order'].index.tolist()
print(cambios)
# Out:
# [185, 371, 557, 743, 929, 1115, 1301, 1487, 1673, 1859, 2045, 2231, 2417, 2603, 2789, 2975, 3161, 3347, 3533, 3719, 3905, 4091, 4277, 4463, 4649, 4835, 5021, 5207, 5393, 5579, 5765, 5951, 6137, 6323, 6509, 6695, 6881, 7067, 7253, 7439, 7625, 7811, 7997, 8183]

# %%
rnd1,rnd2=random.choices(cambios,k=2)

# %% [markdown]
# Dividimos

# %%
gesto1=df1[(df1.index>=rnd1-185)&(df1.index<rnd1)].astype(int)
gesto2=df2[(df2.index>=rnd2-185)&(df2.index<rnd2)].astype(int)

# %%
gesto1[['Acx','Acy','Acz']].plot(title='Gesto 1')
gesto2[['Acx','Acy','Acz']].plot(title='Gesto 2')

# %%
gesto1[['Gx','Gy','Gz']].plot()
gesto2[['Gx','Gy','Gz']].plot()
