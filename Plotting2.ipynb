# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
df1=pd.read_csv('Muestras/Muestras5s/Encender.csv')
df2=pd.read_csv('Muestras/Muestras-Raúl-5Seg/Encender.csv')

# %%
cambios=df1[df1['Tiempo']=='Order'].index.tolist()
print(cambios)
# Out:
# [300, 601, 902, 1203, 1504, 1805, 2106, 2407, 2708, 3009, 3310, 3611, 3912, 4213, 4514, 4815, 5116, 5417, 5718, 6019, 6320, 6621, 6922, 7223, 7524, 7825, 8126, 8427, 8728, 9029, 9330, 9631, 9932, 10233, 10534, 10835, 11136, 11437, 11738, 12039, 12340, 12641, 12942, 13243, 13544, 13845, 14146, 14447, 14748, 15049, 15350, 15651, 15952, 16253, 16554, 16855, 17156, 17457, 17758, 18059, 18360, 18661, 18962, 19263, 19564, 19865, 20166, 20467, 20768, 21069, 21370, 21671, 21972, 22273, 22574, 22875, 23176, 23477, 23778, 24079, 24380, 24681, 24982, 25283, 25584, 25885, 26186, 26487, 26788, 27089, 27390, 27691, 27992, 28293, 28594, 28895, 29196, 29497, 29798, 30099]

# %%
rnd1,rnd2=random.choices(cambios,k=2)

# %% [markdown]
# # Dividimos

# %%
gesto1=df1[(df1.index>=rnd1-300)&(df1.index<rnd1)].astype(int)
gesto2=df2[(df2.index>=rnd2-300)&(df2.index<rnd2)].astype(int)

# %%
gesto1[['Acx','Acy','Acz']].plot(title='Gesto 1')
gesto2[['Acx','Acy','Acz']].plot(title='Gesto 2')

# %%
gesto1[['Gx','Gy','Gz']].plot()
gesto2[['Gx','Gy','Gz']].plot()
